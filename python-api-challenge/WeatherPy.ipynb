# %% [markdown]
# !pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 613

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
api_keys= weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + api_keys

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q={city}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = response["coord"]["lat"]
        city_lng = response["coord"]["lon"]
        city_max_temp = response["main"]["temp_max"]
        city_humidity = response["main"]["humidity"]
        city_clouds = response["clouds"]["all"]
        city_wind = response["wind"]["speed"]
        city_country = response["sys"]["country"]
        city_date = response["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | villa gesell
# City not found. Skipping...
# Processing Record 2 of Set 1 | hithadhoo
# City not found. Skipping...
# Processing Record 3 of Set 1 | nadym
# City not found. Skipping...
# Processing Record 4 of Set 1 | stanley
# City not found. Skipping...
# Processing Record 5 of Set 1 | waitangi
# City not found. Skipping...
# Processing Record 6 of Set 1 | olonkinbyen
# City not found. Skipping...
# Processing Record 7 of Set 1 | mount isa
# City not found. Skipping...
# Processing Record 8 of Set 1 | tura
# City not found. Skipping...
# Processing Record 9 of Set 1 | balotra
# City not found. Skipping...
# Processing Record 10 of Set 1 | chuzhou
# City not found. Skipping...
# Processing Record 11 of Set 1 | west island
# City not found. Skipping...
# Processing Record 12 of Set 1 | adamstown
# City not found. Skipping...
# Processing Record 13 of Set 1 | kudahuvadhoo
# City not found. Skipping...
# Processing Record 14 of Set 1 | toga village
# City not found. Skipping...
# Processing Record 15 of Set 1 | moree
# City not found. Skipping...
# Processing Record 16 of Set 1 | sompeta
# City not found. Skipping...
# Processing Record 17 of Set 1 | grytviken
# City not found. Skipping...
# Processing Record 18 of Set 1 | ilulissat
# City not found. Skipping...
# Processing Record 19 of Set 1 | afaahiti
# City not found. Skipping...
# Processing Record 20 of Set 1 | lebu
# City not found. Skipping...
# Processing Record 21 of Set 1 | sibi
# City not found. Skipping...
# Processing Record 22 of Set 1 | port elizabeth
# City not found. Skipping...
# Processing Record 23 of Set 1 | newman
# City not found. Skipping...
# Processing Record 24 of Set 1 | val-d'or
# City not found. Skipping...
# Processing Record 25 of Set 1 | tvoroyri
# City not found. Skipping...
# Processing Record 26 of Set 1 | bandarbeyla
# City not found. Skipping...
# Processing Record 27 of Set 1 | at taj
# City not found. Skipping...
# Processing Record 28 of Set 1 | lompoc
# City not found. Skipping...
# Processing Record 29 of Set 1 | port-aux-francais
# City not found. Skipping...
# Processing Record 30 of Set 1 | egilsstadir
# City not found. Skipping...
# Processing Record 31 of Set 1 | mawlaik
# City not found. Skipping...
# Processing Record 32 of Set 1 | punta arenas
# City not found. Skipping...
# Processing Record 33 of Set 1 | kanigiri
# City not found. Skipping...
# Processing Record 34 of Set 1 | talnakh
# City not found. Skipping...
# Processing Record 35 of Set 1 | hawaiian paradise park
# City not found. Skipping...
# Processing Record 36 of Set 1 | enewetak
# City not found. Skipping...
# Processing Record 37 of Set 1 | pontianak
# City not found. Skipping...
# Processing Record 38 of Set 1 | takamaka
# City not found. Skipping...
# Processing Record 39 of Set 1 | edinburgh of the seven seas
# City not found. Skipping...
# Processing Record 40 of Set 1 | uturoa
# City not found. Skipping...
# Processing Record 41 of Set 1 | morris
# City not found. Skipping...
# Processing Record 42 of Set 1 | susuman
# City not found. Skipping...
# Processing Record 43 of Set 1 | cafayate
# City not found. Skipping...
# Processing Record 44 of Set 1 | jinchang
# City not found. Skipping...
# Processing Record 32 of Set 11 | tazovsky
# City not found. Skipping...
# Processing Record 33 of Set 11 | sabinanigo
# City not found. Skipping...
# Processing Record 34 of Set 11 | passagem franca
# City not found. Skipping...
# Processing Record 35 of Set 11 | bodo
# City not found. Skipping...
# Processing Record 36 of Set 11 | clayton
# City not found. Skipping...
# Processing Record 37 of Set 11 | lusambo
# City not found. Skipping...
# Processing Record 38 of Set 11 | asau
# City not found. Skipping...
# Processing Record 39 of Set 11 | sabha
# City not found. Skipping...
# Processing Record 40 of Set 11 | tumut
# City not found. Skipping...
# Processing Record 41 of Set 11 | tangalle
# City not found. Skipping...
# Processing Record 42 of Set 11 | kiunga
# City not found. Skipping...
# Processing Record 43 of Set 11 | weiser
# City not found. Skipping...
# Processing Record 44 of Set 11 | chul'man
# City not found. Skipping...
# Processing Record 45 of Set 11 | jutai
# City not found. Skipping...
# Processing Record 46 of Set 11 | severnoye
# City not found. Skipping...
# Processing Record 47 of Set 11 | bamyan
# City not found. Skipping...
# Processing Record 48 of Set 11 | nacala
# City not found. Skipping...
# Processing Record 49 of Set 11 | nuku'alofa
# City not found. Skipping...
# Processing Record 0 of Set 12 | bikaner
# City not found. Skipping...
# Processing Record 1 of Set 12 | xai-xai
# City not found. Skipping...
# Processing Record 2 of Set 12 | calliope
# City not found. Skipping...
# Processing Record 3 of Set 12 | linxia chengguanzhen
# City not found. Skipping...
# Processing Record 4 of Set 12 | ewo
# City not found. Skipping...
# Processing Record 5 of Set 12 | harper
# City not found. Skipping...
# Processing Record 6 of Set 12 | ghanzi
# City not found. Skipping...
# Processing Record 7 of Set 12 | churapcha
# City not found. Skipping...
# Processing Record 8 of Set 12 | nyurba
# City not found. Skipping...
# Processing Record 9 of Set 12 | mugia
# City not found. Skipping...
# Processing Record 10 of Set 12 | akureyri
# City not found. Skipping...
# Processing Record 11 of Set 12 | mariehamn
# City not found. Skipping...
# Processing Record 12 of Set 12 | burabay
# City not found. Skipping...
# Processing Record 13 of Set 12 | puerto baquerizo moreno
# City not found. Skipping...
# Processing Record 14 of Set 12 | aleksandrovsk
# City not found. Skipping...
# Processing Record 15 of Set 12 | mokrous
# City not found. Skipping...
# Processing Record 16 of Set 12 | contamana
# City not found. Skipping...
# Processing Record 17 of Set 12 | krasnyy chikoy
# City not found. Skipping...
# Processing Record 18 of Set 12 | kaspiyskiy
# City not found. Skipping...
# Processing Record 19 of Set 12 | chebarkul'
# City not found. Skipping...
# Processing Record 20 of Set 12 | lingsugur
# City not found. Skipping...
# Processing Record 21 of Set 12 | altai
# City not found. Skipping...
# Processing Record 22 of Set 12 | xam nua
# City not found. Skipping...
# Processing Record 23 of Set 12 | hami
# City not found. Skipping...
# Processing Record 24 of Set 12 | seven pagodas
# City not found. Skipping...
# Processing Record 25 of Set 12 | yigo village
# City not found. Skipping...
# Processing Record 26 of Set 12 | ar rahad
# City not found. Skipping...
# Processing Record 27 of Set 12 | south windsor
# City not found. Skipping...
# Processing Record 28 of Set 12 | kribi
# City not found. Skipping...
# Processing Record 29 of Set 12 | collie
# City not found. Skipping...
# Processing Record 30 of Set 12 | igarka
# City not found. Skipping...
# Processing Record 31 of Set 12 | sao vicente
# City not found. Skipping...
# Processing Record 32 of Set 12 | princeville
# City not found. Skipping...
# Processing Record 33 of Set 12 | villa rica
# City not found. Skipping...
# Processing Record 34 of Set 12 | revda
# City not found. Skipping...
# Processing Record 35 of Set 12 | albu kamal
# City not found. Skipping...
# Processing Record 36 of Set 12 | raebareli
# City not found. Skipping...
# Processing Record 37 of Set 12 | ujae
# City not found. Skipping...
# Processing Record 38 of Set 12 | mhamid
# City not found. Skipping...
# Processing Record 39 of Set 12 | lagos
# City not found. Skipping...
# Processing Record 40 of Set 12 | isle of lewis
# City not found. Skipping...
# Processing Record 41 of Set 12 | tabuk
# City not found. Skipping...
# Processing Record 42 of Set 12 | khorugh
# City not found. Skipping...
# Processing Record 43 of Set 12 | askoy
# City not found. Skipping...
# Processing Record 44 of Set 12 | san patricio
# City not found. Skipping...
# Processing Record 45 of Set 12 | parabel'
# City not found. Skipping...
# Processing Record 46 of Set 12 | kenora
# City not found. Skipping...
# Processing Record 47 of Set 12 | khorixas
# City not found. Skipping...
# Processing Record 48 of Set 12 | coahuayana de hidalgo
# City not found. Skipping...
# Processing Record 49 of Set 12 | luanda
# City not found. Skipping...
# Processing Record 0 of Set 13 | la palma
# City not found. Skipping...
# Processing Record 1 of Set 13 | colares
# City not found. Skipping...
# Processing Record 2 of Set 13 | ghatanji
# City not found. Skipping...
# Processing Record 3 of Set 13 | colonia
# City not found. Skipping...
# Processing Record 4 of Set 13 | piraeus
# City not found. Skipping...
# Processing Record 5 of Set 13 | murun-kuren
# City not found. Skipping...
# Processing Record 6 of Set 13 | greymouth
# City not found. Skipping...
# Processing Record 7 of Set 13 | qal'at bishah
# City not found. Skipping...
# Processing Record 8 of Set 13 | betio village
# City not found. Skipping...
# Processing Record 9 of Set 13 | bereeda
# City not found. Skipping...
# Processing Record 10 of Set 13 | recani
# City not found. Skipping...
# Processing Record 11 of Set 13 | ulsteinvik
# City not found. Skipping...
# Processing Record 12 of Set 13 | ati
# City not found. Skipping...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# Series([], dtype: int64)

# %%
# Display sample data
city_data_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.figure(figsize=(10, 6))
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], marker='o', color='blue', edgecolors='black', alpha=0.7)

# Incorporate the other graph properties
plt.title('City Latitude vs. Max Temperature', fontsize=14)  # Title of the plot
plt.xlabel('Latitude', fontsize=12)  # Label for the x-axis
plt.ylabel('Max Temperature (°C)', fontsize=12)  # Label for the y-axis
plt.grid(True)  # Enable grid for better readability

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Lat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Build scatter plot for latitude vs. temperature
#       2 plt.figure(figsize=(10, 6))
# ----> 3 plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], marker='o', color='blue', edgecolors='black', alpha=0.7)
#       5 # Incorporate the other graph properties
#       6 plt.title('City Latitude vs. Max Temperature', fontsize=14)  # Title of the plot
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Lat'

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.figure(figsize=(10, 6))
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], marker='o', color='green', edgecolors='black', alpha=0.7)

# Incorporate the other graph properties
plt.title('City Latitude vs. Humidity', fontsize=14)  # Title of the plot
plt.xlabel('Latitude', fontsize=12)  # Label for the x-axis
plt.ylabel('Humidity (%)', fontsize=12)  # Label for the y-axis
plt.grid(True)  # Enable grid for better readability

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.figure(figsize=(10, 6))
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], marker='o', color='green', edgecolors='black', alpha=0.7)

# Incorporate the other graph properties
plt.title('City Latitude vs. Cloudiness', fontsize=14)  # Title of the plot
plt.xlabel('Latitude', fontsize=12)  # Label for the x-axis
plt.ylabel('Cloudiness (%)', fontsize=12)  # Label for the y-axis
plt.grid(True)  # Enable grid for better readability

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.figure(figsize=(10, 6))
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], marker='o', color='green', edgecolors='black', alpha=0.7)

# Incorporate the other graph properties
plt.title('City Latitude vs. Wind Speed', fontsize=14)  # Title of the plot
plt.xlabel('Latitude', fontsize=12)  # Label for the x-axis
plt.ylabel('Wind Speed (m/s)', fontsize=12)  # Label for the y-axis
plt.grid(True)  # Enable grid for better readability

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x, y, x_label, y_label, title, filename):
    slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
    
    # Create the regression line
    regression_line = slope * np.array(x) + intercept

    # Create the plot
    plt.figure(figsize=(10, 6))
    plt.scatter(x, y, marker='o', color='blue', edgecolors='black', alpha=0.7, label='Data Points')  # Scatter plot
    plt.plot(x, regression_line, color='red', label=f'Linear Regression Line: y = {slope:.2f}x + {intercept:.2f}')  # Regression line

    # Add titles and labels
    plt.title(title, fontsize=14)
    plt.xlabel(x_label, fontsize=12)
    plt.ylabel(y_label, fontsize=12)
    plt.grid(True)
    plt.legend()

    # Save the figure
    plt.savefig(filename)

    # Show the plot
    plt.show()

    # Return the linear regression details (slope, intercept, R-squared, p-value)
    return slope, intercept, r_value**2, p_value, std_err

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
slope_north, intercept_north, r_value_north, p_value_north, std_err_north = plot_linear_regression(
    northern_hemi_df['Lat'], 
    northern_hemi_df['Max Temp'], 
    'Latitude', 
    'Max Temperature (°C)', 
    'Northern Hemisphere: Temperature vs. Latitude', 
    'output_data/North_Temperature_vs_Latitude.png'
)

# %%
# Linear regression on Southern Hemisphere
slope_south, intercept_south, r_value_south, p_value_south, std_err_south = plot_linear_regression(
    southern_hemi_df['Lat'], 
    southern_hemi_df['Max Temp'], 
    'Latitude', 
    'Max Temperature (°C)', 
    'Southern Hemisphere: Temperature vs. Latitude', 
    'output_data/South_Temperature_vs_Latitude.png'
)

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Perform linear regression: latitude vs. humidity
slope, intercept, r_value, p_value, std_err = stats.linregress(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])

# Create the regression line based on the linear regression output
regression_line = slope * np.array(northern_hemi_df['Lat']) + intercept

# Create the scatter plot with the regression line
plt.figure(figsize=(10, 6))
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], color='blue', edgecolors='black', alpha=0.7, label='Data Points')

# Plot the regression line
plt.plot(northern_hemi_df['Lat'], regression_line, color='red', label=f'Linear Regression Line: y = {slope:.2f}x + {intercept:.2f}')

# Add titles and labels
plt.title('Northern Hemisphere: Latitude vs. Humidity', fontsize=14)
plt.xlabel('Latitude', fontsize=12)
plt.ylabel('Humidity (%)', fontsize=12)
plt.grid(True)
plt.legend()

# Save the plot
plt.savefig("output_data/Northern_Hemisphere_Latitude_vs_Humidity.png")

# Show the plot
plt.show()

# Print the linear regression statistics
print(f"Linear Regression (Northern Hemisphere):")
print(f"Slope: {slope:.2f}")
print(f"Intercept: {intercept:.2f}")
print(f"R-squared: {r_value**2:.2f}")
print(f"P-value: {p_value:.4f}")
print(f"Standard Error: {std_err:.4f}")

# %%
# Southern Hemisphere

# Perform linear regression: latitude vs. humidity
slope, intercept, r_value, p_value, std_err = stats.linregress(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])

# Create the regression line based on the linear regression output
regression_line = slope * np.array(southern_hemi_df['Lat']) + intercept

# Create the scatter plot with the regression line
plt.figure(figsize=(10, 6))
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], color='green', edgecolors='black', alpha=0.7, label='Data Points')

# Plot the regression line
plt.plot(southern_hemi_df['Lat'], regression_line, color='red', label=f'Linear Regression Line: y = {slope:.2f}x + {intercept:.2f}')

# Add titles and labels
plt.title('Southern Hemisphere: Latitude vs. Humidity', fontsize=14)
plt.xlabel('Latitude', fontsize=12)
plt.ylabel('Humidity (%)', fontsize=12)
plt.grid(True)
plt.legend()

# Save the plot
plt.savefig("output_data/Southern_Hemisphere_Latitude_vs_Humidity.png")

# Show the plot
plt.show()

# Print the linear regression statistics
print(f"Linear Regression (Southern Hemisphere):")
print(f"Slope: {slope:.2f}")
print(f"Intercept: {intercept:.2f}")
print(f"R-squared: {r_value**2:.2f}")
print(f"P-value: {p_value:.4f}")
print(f"Standard Error: {std_err:.4f}")

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Filter data for Northern Hemisphere (latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Perform linear regression: latitude vs. cloudiness
slope, intercept, r_value, p_value, std_err = stats.linregress(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])

# Create the regression line based on the linear regression output
regression_line = slope * np.array(northern_hemi_df['Lat']) + intercept

# Create the scatter plot with the regression line
plt.figure(figsize=(10, 6))
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'], color='purple', edgecolors='black', alpha=0.7, label='Data Points')

# Plot the regression line
plt.plot(northern_hemi_df['Lat'], regression_line, color='red', label=f'Linear Regression Line: y = {slope:.2f}x + {intercept:.2f}')

# Add titles and labels
plt.title('Northern Hemisphere: Latitude vs. Cloudiness', fontsize=14)
plt.xlabel('Latitude', fontsize=12)
plt.ylabel('Cloudiness (%)', fontsize=12)
plt.grid(True)
plt.legend()

# Save the plot
plt.savefig("output_data/Northern_Hemisphere_Latitude_vs_Cloudiness.png")

# Show the plot
plt.show()

# Print the linear regression statistics
print(f"Linear Regression (Northern Hemisphere) for Cloudiness:")
print(f"Slope: {slope:.2f}")
print(f"Intercept: {intercept:.2f}")
print(f"R-squared: {r_value**2:.2f}")
print(f"P-value: {p_value:.4f}")
print(f"Standard Error: {std_err:.4f}")

# %%
# Southern Hemisphere
# Filter data for Southern Hemisphere (latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Perform linear regression: latitude vs. cloudiness
slope, intercept, r_value, p_value, std_err = stats.linregress(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])

# Create the regression line based on the linear regression output
regression_line = slope * np.array(southern_hemi_df['Lat']) + intercept

# Create the scatter plot with the regression line
plt.figure(figsize=(10, 6))
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'], color='orange', edgecolors='black', alpha=0.7, label='Data Points')

# Plot the regression line
plt.plot(southern_hemi_df['Lat'], regression_line, color='red', label=f'Linear Regression Line: y = {slope:.2f}x + {intercept:.2f}')

# Add titles and labels
plt.title('Southern Hemisphere: Latitude vs. Cloudiness', fontsize=14)
plt.xlabel('Latitude', fontsize=12)
plt.ylabel('Cloudiness (%)', fontsize=12)
plt.grid(True)
plt.legend()

# Save the plot
plt.savefig("output_data/Southern_Hemisphere_Latitude_vs_Cloudiness.png")

# Show the plot
plt.show()

# Print the linear regression statistics
print(f"Linear Regression (Southern Hemisphere) for Cloudiness:")
print(f"Slope: {slope:.2f}")
print(f"Intercept: {intercept:.2f}")
print(f"R-squared: {r_value**2:.2f}")
print(f"P-value: {p_value:.4f}")
print(f"Standard Error: {std_err:.4f}")

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Filter data for Northern Hemisphere (latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Perform linear regression: latitude vs. wind speed
slope, intercept, r_value, p_value, std_err = stats.linregress(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])

# Create the regression line based on the linear regression output
regression_line = slope * np.array(northern_hemi_df['Lat']) + intercept

# Create the scatter plot with the regression line
plt.figure(figsize=(10, 6))
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'], color='blue', edgecolors='black', alpha=0.7, label='Data Points')

# Plot the regression line
plt.plot(northern_hemi_df['Lat'], regression_line, color='red', label=f'Linear Regression Line: y = {slope:.2f}x + {intercept:.2f}')

# Add titles and labels
plt.title('Northern Hemisphere: Latitude vs. Wind Speed', fontsize=14)
plt.xlabel('Latitude', fontsize=12)
plt.ylabel('Wind Speed (m/s)', fontsize=12)
plt.grid(True)
plt.legend()

# Save the plot
plt.savefig("output_data/Northern_Hemisphere_Latitude_vs_Wind_Speed.png")

# Show the plot
plt.show()

# Print the linear regression statistics
print(f"Linear Regression (Northern Hemisphere) for Wind Speed:")
print(f"Slope: {slope:.2f}")
print(f"Intercept: {intercept:.2f}")
print(f"R-squared: {r_value**2:.2f}")
print(f"P-value: {p_value:.4f}")
print(f"Standard Error: {std_err:.4f}")

# %%
# Southern Hemisphere
# Filter data for Southern Hemisphere (latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Perform linear regression: latitude vs. wind speed
slope, intercept, r_value, p_value, std_err = stats.linregress(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])

# Create the regression line based on the linear regression output
regression_line = slope * np.array(southern_hemi_df['Lat']) + intercept

# Create the scatter plot with the regression line
plt.figure(figsize=(10, 6))
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], color='green', edgecolors='black', alpha=0.7, label='Data Points')

# Plot the regression line
plt.plot(southern_hemi_df['Lat'], regression_line, color='red', label=f'Linear Regression Line: y = {slope:.2f}x + {intercept:.2f}')

# Add titles and labels
plt.title('Southern Hemisphere: Latitude vs. Wind Speed', fontsize=14)
plt.xlabel('Latitude', fontsize=12)
plt.ylabel('Wind Speed (m/s)', fontsize=12)
plt.grid(True)
plt.legend()

# Save the plot
plt.savefig("output_data/Southern_Hemisphere_Latitude_vs_Wind_Speed.png")

# Show the plot
plt.show()

# Print the linear regression statistics
print(f"Linear Regression (Southern Hemisphere) for Wind Speed:")
print(f"Slope: {slope:.2f}")
print(f"Intercept: {intercept:.2f}")
print(f"R-squared: {r_value**2:.2f}")
print(f"P-value: {p_value:.4f}")
print(f"Standard Error: {std_err:.4f}")

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
