# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (0.0.6)
# Requirement already satisfied: kdtree>=0.12 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 589

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
api_keys= weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={api_keys}&units=metric"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = response["coord"]["lat"]
        city_lng = response["coord"]["lon"]
        city_max_temp = response["main"]["temp_max"]
        city_humidity = response["main"]["humidity"]
        city_clouds = response["clouds"]["all"]
        city_wind = response["wind"]["speed"]
        city_country = response["sys"]["country"]
        city_date = response["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# City not found. Skipping...
# Processing Record 2 of Set 1 | port-aux-francais
# City not found. Skipping...
# Processing Record 3 of Set 1 | waitangi
# City not found. Skipping...
# Processing Record 4 of Set 1 | punta arenas
# City not found. Skipping...
# Processing Record 5 of Set 1 | edinburgh of the seven seas
# City not found. Skipping...
# Processing Record 6 of Set 1 | sakakah
# City not found. Skipping...
# Processing Record 7 of Set 1 | utrik
# City not found. Skipping...
# Processing Record 8 of Set 1 | mpanda
# City not found. Skipping...
# Processing Record 9 of Set 1 | fisterra
# City not found. Skipping...
# Processing Record 10 of Set 1 | newnham
# City not found. Skipping...
# Processing Record 11 of Set 1 | ribeira grande
# City not found. Skipping...
# Processing Record 12 of Set 1 | kokopo
# City not found. Skipping...
# Processing Record 13 of Set 1 | papatowai
# City not found. Skipping...
# Processing Record 14 of Set 1 | okhotsk
# City not found. Skipping...
# Processing Record 15 of Set 1 | geraldton
# City not found. Skipping...
# Processing Record 16 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 17 of Set 1 | iqaluit
# City not found. Skipping...
# Processing Record 18 of Set 1 | fort mcmurray
# City not found. Skipping...
# Processing Record 19 of Set 1 | mazagao
# City not found. Skipping...
# Processing Record 20 of Set 1 | longyearbyen
# City not found. Skipping...
# Processing Record 21 of Set 1 | dzhangala
# City not found. Skipping...
# Processing Record 22 of Set 1 | sisimiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | cacapava
# City not found. Skipping...
# Processing Record 24 of Set 1 | yellowknife
# City not found. Skipping...
# Processing Record 25 of Set 1 | kailua-kona
# City not found. Skipping...
# Processing Record 26 of Set 1 | weno
# City not found. Skipping...
# Processing Record 27 of Set 1 | ust-nera
# City not found. Skipping...
# Processing Record 28 of Set 1 | belmonte
# City not found. Skipping...
# Processing Record 29 of Set 1 | blackmans bay
# City not found. Skipping...
# Processing Record 30 of Set 1 | port mathurin
# City not found. Skipping...
# Processing Record 31 of Set 1 | cherdyn'
# City not found. Skipping...
# Processing Record 32 of Set 1 | albany
# City not found. Skipping...
# Processing Record 33 of Set 1 | puerto san jose
# City not found. Skipping...
# Processing Record 34 of Set 1 | bogorodsk
# City not found. Skipping...
# Processing Record 35 of Set 1 | adamstown
# City not found. Skipping...
# Processing Record 36 of Set 1 | boca chica
# City not found. Skipping...
# Processing Record 37 of Set 1 | ash shafa
# City not found. Skipping...
# Processing Record 38 of Set 1 | tintafor
# City not found. Skipping...
# Processing Record 39 of Set 1 | west island
# City not found. Skipping...
# Processing Record 40 of Set 1 | puerto natales
# City not found. Skipping...
# Processing Record 41 of Set 1 | carnarvon
# City not found. Skipping...
# Processing Record 42 of Set 1 | yeppoon
# City not found. Skipping...
# Processing Record 43 of Set 1 | whitehorse
# City not found. Skipping...
# Processing Record 44 of Set 1 | broken hill
# City not found. Skipping...
# Processing Record 45 of Set 1 | tuzi
# City not found. Skipping...
# Processing Record 46 of Set 1 | puerto ayora
# City not found. Skipping...
# Processing Record 47 of Set 1 | grytviken
# City not found. Skipping...
# Processing Record 48 of Set 1 | tadine
# City not found. Skipping...
# Processing Record 49 of Set 1 | tura
# City not found. Skipping...
# Processing Record 50 of Set 1 | sao jose da coroa grande
# City not found. Skipping...
# Processing Record 0 of Set 2 | lihue
# City not found. Skipping...
# Processing Record 1 of Set 2 | ojinaga
# City not found. Skipping...
# Processing Record 2 of Set 2 | ocean shores
# City not found. Skipping...
# Processing Record 3 of Set 2 | dongola
# City not found. Skipping...
# Processing Record 4 of Set 2 | isafjordur
# City not found. Skipping...
# Processing Record 5 of Set 2 | chonchi
# City not found. Skipping...
# Processing Record 6 of Set 2 | usinsk
# City not found. Skipping...
# Processing Record 7 of Set 2 | nagqu
# City not found. Skipping...
# Processing Record 8 of Set 2 | jamestown
# City not found. Skipping...
# Processing Record 9 of Set 2 | bethel
# City not found. Skipping...
# Processing Record 10 of Set 2 | buncrana
# City not found. Skipping...
# Processing Record 11 of Set 2 | invercargill
# City not found. Skipping...
# Processing Record 12 of Set 2 | villanueva
# City not found. Skipping...
# Processing Record 13 of Set 2 | kerikeri
# City not found. Skipping...
# Processing Record 14 of Set 2 | ar rutbah
# City not found. Skipping...
# Processing Record 15 of Set 2 | anloga
# City not found. Skipping...
# Processing Record 16 of Set 2 | kodiak
# City not found. Skipping...
# Processing Record 17 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 18 of Set 2 | hermanus
# City not found. Skipping...
# Processing Record 19 of Set 2 | nova sintra
# City not found. Skipping...
# Processing Record 20 of Set 2 | udachny
# City not found. Skipping...
# Processing Record 21 of Set 2 | candelaria
# City not found. Skipping...
# Processing Record 22 of Set 2 | inirida
# City not found. Skipping...
# Processing Record 23 of Set 2 | kirensk
# City not found. Skipping...
# Processing Record 24 of Set 2 | bredasdorp
# City not found. Skipping...
# Processing Record 25 of Set 2 | namibe
# City not found. Skipping...
# Processing Record 26 of Set 2 | wailua homesteads
# City not found. Skipping...
# Processing Record 27 of Set 2 | yuzhno-kurilsk
# City not found. Skipping...
# Processing Record 28 of Set 2 | whakatane
# City not found. Skipping...
# Processing Record 29 of Set 2 | crane
# City not found. Skipping...
# Processing Record 30 of Set 2 | georgetown
# City not found. Skipping...
# Processing Record 31 of Set 2 | naze
# City not found. Skipping...
# Processing Record 32 of Set 2 | tiksi
# City not found. Skipping...
# Processing Record 33 of Set 2 | talnakh
# City not found. Skipping...
# Processing Record 34 of Set 2 | luderitz
# City not found. Skipping...
# Processing Record 35 of Set 2 | poyang
# City not found. Skipping...
# Processing Record 36 of Set 2 | west end
# City not found. Skipping...
# Processing Record 37 of Set 2 | governor's harbour
# City not found. Skipping...
# Processing Record 38 of Set 2 | port alfred
# City not found. Skipping...
# Processing Record 39 of Set 2 | lorengau
# City not found. Skipping...
# Processing Record 40 of Set 2 | saint-denis
# City not found. Skipping...
# Processing Record 41 of Set 2 | vadso
# City not found. Skipping...
# Processing Record 42 of Set 2 | vorkuta
# City not found. Skipping...
# Processing Record 43 of Set 2 | cody
# City not found. Skipping...
# Processing Record 44 of Set 2 | trondheim
# City not found. Skipping...
# Processing Record 45 of Set 2 | vila franca do campo
# City not found. Skipping...
# Processing Record 46 of Set 2 | malango
# City not found. Skipping...
# Processing Record 47 of Set 2 | toga village
# City not found. Skipping...
# Processing Record 48 of Set 2 | ahau
# City not found. Skipping...
# Processing Record 49 of Set 2 | college
# City not found. Skipping...
# Processing Record 0 of Set 3 | santa ponsa
# City not found. Skipping...
# Processing Record 1 of Set 3 | puerto el triunfo
# City not found. Skipping...
# Processing Record 2 of Set 3 | china
# City not found. Skipping...
# Processing Record 3 of Set 3 | east london
# City not found. Skipping...
# Processing Record 4 of Set 3 | mancio lima
# City not found. Skipping...
# Processing Record 5 of Set 3 | taltal
# City not found. Skipping...
# Processing Record 6 of Set 3 | ola
# City not found. Skipping...
# Processing Record 7 of Set 3 | arraial do cabo
# City not found. Skipping...
# Processing Record 8 of Set 3 | kuruman
# City not found. Skipping...
# Processing Record 9 of Set 3 | dunedin
# City not found. Skipping...
# Processing Record 10 of Set 3 | keflavik
# City not found. Skipping...
# Processing Record 11 of Set 3 | novodvinsk
# City not found. Skipping...
# Processing Record 12 of Set 3 | jinchang
# City not found. Skipping...
# Processing Record 13 of Set 3 | dudinka
# City not found. Skipping...
# Processing Record 14 of Set 3 | kununurra
# City not found. Skipping...
# Processing Record 15 of Set 3 | tshikapa
# City not found. Skipping...
# Processing Record 16 of Set 3 | saipan
# City not found. Skipping...
# Processing Record 17 of Set 3 | nadym
# City not found. Skipping...
# Processing Record 18 of Set 3 | maun
# City not found. Skipping...
# Processing Record 19 of Set 3 | noosa heads
# City not found. Skipping...
# Processing Record 20 of Set 3 | hamilton
# City not found. Skipping...
# Processing Record 21 of Set 3 | mar del plata
# City not found. Skipping...
# Processing Record 22 of Set 3 | nova londrina
# City not found. Skipping...
# Processing Record 23 of Set 3 | catarman
# City not found. Skipping...
# Processing Record 24 of Set 3 | olonkinbyen
# City not found. Skipping...
# Processing Record 25 of Set 3 | badger
# City not found. Skipping...
# Processing Record 26 of Set 3 | palmeira das missoes
# City not found. Skipping...
# Processing Record 27 of Set 3 | fort bragg
# City not found. Skipping...
# Processing Record 28 of Set 3 | constantia
# City not found. Skipping...
# Processing Record 29 of Set 3 | hoxtolgay
# City not found. Skipping...
# Processing Record 30 of Set 3 | uzgen
# City not found. Skipping...
# Processing Record 31 of Set 3 | alaghsas
# City not found. Skipping...
# Processing Record 32 of Set 3 | alice springs
# City not found. Skipping...
# Processing Record 33 of Set 3 | mikuni
# City not found. Skipping...
# Processing Record 34 of Set 3 | hithadhoo
# City not found. Skipping...
# Processing Record 35 of Set 3 | cole harbour
# City not found. Skipping...
# Processing Record 36 of Set 3 | rmi capitol
# City not found. Skipping...
# Processing Record 37 of Set 3 | dibba al-fujairah
# City not found. Skipping...
# Processing Record 38 of Set 3 | ingeniero jacobacci
# City not found. Skipping...
# Processing Record 39 of Set 3 | pisco
# City not found. Skipping...
# Processing Record 40 of Set 3 | atafu village
# City not found. Skipping...
# Processing Record 41 of Set 3 | amga
# City not found. Skipping...
# Processing Record 42 of Set 3 | augusto correa
# City not found. Skipping...
# Processing Record 43 of Set 3 | myeik
# City not found. Skipping...
# Processing Record 44 of Set 3 | selfoss
# City not found. Skipping...
# Processing Record 45 of Set 3 | himatnagar
# City not found. Skipping...
# Processing Record 46 of Set 3 | la passe
# City not found. Skipping...
# Processing Record 47 of Set 3 | nuku'alofa
# City not found. Skipping...
# Processing Record 48 of Set 3 | zhumysker
# City not found. Skipping...
# Processing Record 49 of Set 3 | tazovsky
# City not found. Skipping...
# Processing Record 0 of Set 4 | kapuskasing
# City not found. Skipping...
# Processing Record 1 of Set 4 | olyokminsk
# City not found. Skipping...
# Processing Record 2 of Set 4 | lerwick
# City not found. Skipping...
# Processing Record 3 of Set 4 | lazaro cardenas
# City not found. Skipping...
# Processing Record 4 of Set 4 | touros
# City not found. Skipping...
# Processing Record 5 of Set 4 | howard springs
# City not found. Skipping...
# Processing Record 6 of Set 4 | falun
# City not found. Skipping...
# Processing Record 7 of Set 4 | razole
# City not found. Skipping...
# Processing Record 8 of Set 4 | kavaratti
# City not found. Skipping...
# Processing Record 9 of Set 4 | xifeng
# City not found. Skipping...
# Processing Record 10 of Set 4 | alpine
# City not found. Skipping...
# Processing Record 11 of Set 4 | bilibino
# City not found. Skipping...
# Processing Record 12 of Set 4 | hawaiian paradise park
# City not found. Skipping...
# Processing Record 13 of Set 4 | bodo
# City not found. Skipping...
# Processing Record 14 of Set 4 | turkeli
# City not found. Skipping...
# Processing Record 15 of Set 4 | margaret river
# City not found. Skipping...
# Processing Record 16 of Set 4 | mirnyy
# City not found. Skipping...
# Processing Record 17 of Set 4 | kil'mez'
# City not found. Skipping...
# Processing Record 18 of Set 4 | sayula de aleman
# City not found. Skipping...
# Processing Record 19 of Set 4 | happy valley-goose bay
# City not found. Skipping...
# Processing Record 20 of Set 4 | poronaysk
# City not found. Skipping...
# Processing Record 21 of Set 4 | kolonia town
# City not found. Skipping...
# Processing Record 22 of Set 4 | pawni
# City not found. Skipping...
# Processing Record 23 of Set 4 | qaqortoq
# City not found. Skipping...
# Processing Record 24 of Set 4 | nambucca
# City not found. Skipping...
# Processing Record 25 of Set 4 | dawei
# City not found. Skipping...
# Processing Record 26 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 27 of Set 4 | port douglas
# City not found. Skipping...
# Processing Record 28 of Set 4 | punta del este
# City not found. Skipping...
# Processing Record 29 of Set 4 | dzilam gonzalez
# City not found. Skipping...
# Processing Record 30 of Set 4 | ilulissat
# City not found. Skipping...
# Processing Record 31 of Set 4 | malkapur
# City not found. Skipping...
# Processing Record 32 of Set 4 | ramnagar
# City not found. Skipping...
# Processing Record 33 of Set 4 | portland
# City not found. Skipping...
# Processing Record 34 of Set 4 | thompson
# City not found. Skipping...
# Processing Record 35 of Set 4 | vilyuchinsk
# City not found. Skipping...
# Processing Record 36 of Set 4 | port shepstone
# City not found. Skipping...
# Processing Record 37 of Set 4 | mineros
# City not found. Skipping...
# Processing Record 38 of Set 4 | anan
# City not found. Skipping...
# Processing Record 39 of Set 4 | avarua
# City not found. Skipping...
# Processing Record 40 of Set 4 | tanggu
# City not found. Skipping...
# Processing Record 41 of Set 4 | leland
# City not found. Skipping...
# Processing Record 42 of Set 4 | kiruna
# City not found. Skipping...
# Processing Record 43 of Set 4 | port elizabeth
# City not found. Skipping...
# Processing Record 44 of Set 4 | pandan
# City not found. Skipping...
# Processing Record 45 of Set 4 | necochea
# City not found. Skipping...
# Processing Record 46 of Set 4 | hanko
# City not found. Skipping...
# Processing Record 47 of Set 4 | lebu
# City not found. Skipping...
# Processing Record 48 of Set 4 | santana
# City not found. Skipping...
# Processing Record 49 of Set 4 | palikir - national government center
# City not found. Skipping...
# Processing Record 0 of Set 5 | khandyga
# City not found. Skipping...
# Processing Record 1 of Set 5 | antonio enes
# City not found. Skipping...
# Processing Record 2 of Set 5 | tsiombe
# City not found. Skipping...
# Processing Record 3 of Set 5 | kuningan
# City not found. Skipping...
# Processing Record 4 of Set 5 | el centro
# City not found. Skipping...
# Processing Record 5 of Set 5 | penzance
# City not found. Skipping...
# Processing Record 6 of Set 5 | lengshuitan
# City not found. Skipping...
# Processing Record 7 of Set 5 | ciutadella
# City not found. Skipping...
# Processing Record 8 of Set 5 | kone
# City not found. Skipping...
# Processing Record 9 of Set 5 | yermentau
# City not found. Skipping...
# Processing Record 10 of Set 5 | enewetak
# City not found. Skipping...
# Processing Record 11 of Set 5 | kuraymah
# City not found. Skipping...
# Processing Record 12 of Set 5 | mandalgovi
# City not found. Skipping...
# Processing Record 13 of Set 5 | port washington
# City not found. Skipping...
# Processing Record 14 of Set 5 | tolanaro
# City not found. Skipping...
# Processing Record 15 of Set 5 | honiara
# City not found. Skipping...
# Processing Record 16 of Set 5 | simpang
# City not found. Skipping...
# Processing Record 17 of Set 5 | copala
# City not found. Skipping...
# Processing Record 18 of Set 5 | kinana
# City not found. Skipping...
# Processing Record 19 of Set 5 | nassau
# City not found. Skipping...
# Processing Record 20 of Set 5 | remire-montjoly
# City not found. Skipping...
# Processing Record 21 of Set 5 | mount gambier
# City not found. Skipping...
# Processing Record 22 of Set 5 | sitka
# City not found. Skipping...
# Processing Record 23 of Set 5 | dampit
# City not found. Skipping...
# Processing Record 24 of Set 5 | tranas
# City not found. Skipping...
# Processing Record 25 of Set 5 | tralee
# City not found. Skipping...
# Processing Record 26 of Set 5 | bubaque
# City not found. Skipping...
# Processing Record 27 of Set 5 | taoudenni
# City not found. Skipping...
# Processing Record 28 of Set 5 | nouadhibou
# City not found. Skipping...
# Processing Record 29 of Set 5 | ghadamis
# City not found. Skipping...
# Processing Record 30 of Set 5 | bovalino superiore
# City not found. Skipping...
# Processing Record 31 of Set 5 | 'izbat al burj
# City not found. Skipping...
# Processing Record 32 of Set 5 | st anne
# City not found. Skipping...
# Processing Record 33 of Set 5 | manadhoo
# City not found. Skipping...
# Processing Record 34 of Set 5 | kisangani
# City not found. Skipping...
# Processing Record 35 of Set 5 | inhambane
# City not found. Skipping...
# Processing Record 36 of Set 5 | buka
# City not found. Skipping...
# Processing Record 37 of Set 5 | kristiansund
# City not found. Skipping...
# Processing Record 38 of Set 5 | reggane
# City not found. Skipping...
# Processing Record 39 of Set 5 | pacific grove
# City not found. Skipping...
# Processing Record 40 of Set 5 | al jawf
# City not found. Skipping...
# Processing Record 41 of Set 5 | dikhil
# City not found. Skipping...
# Processing Record 42 of Set 5 | giado
# City not found. Skipping...
# Processing Record 43 of Set 5 | lichinga
# City not found. Skipping...
# Processing Record 44 of Set 5 | hammerfest
# City not found. Skipping...
# Processing Record 45 of Set 5 | bereznik
# City not found. Skipping...
# Processing Record 46 of Set 5 | merizo village
# City not found. Skipping...
# Processing Record 47 of Set 5 | rundu
# City not found. Skipping...
# Processing Record 48 of Set 5 | smithers
# City not found. Skipping...
# Processing Record 49 of Set 5 | barreirinhas
# City not found. Skipping...
# Processing Record 0 of Set 6 | stanley
# City not found. Skipping...
# Processing Record 1 of Set 6 | sainte-menehould
# City not found. Skipping...
# Processing Record 2 of Set 6 | st. john's
# City not found. Skipping...
# Processing Record 3 of Set 6 | bojnurd
# City not found. Skipping...
# Processing Record 4 of Set 6 | salekhard
# City not found. Skipping...
# Processing Record 5 of Set 6 | luba
# City not found. Skipping...
# Processing Record 6 of Set 6 | huarmey
# City not found. Skipping...
# Processing Record 7 of Set 6 | ust'-ilimsk
# City not found. Skipping...
# Processing Record 8 of Set 6 | kupang
# City not found. Skipping...
# Processing Record 9 of Set 6 | machico
# City not found. Skipping...
# Processing Record 10 of Set 6 | afaahiti
# City not found. Skipping...
# Processing Record 11 of Set 6 | tucuma
# City not found. Skipping...
# Processing Record 12 of Set 6 | barysaw
# City not found. Skipping...
# Processing Record 13 of Set 6 | mandiana
# City not found. Skipping...
# Processing Record 14 of Set 6 | new norfolk
# City not found. Skipping...
# Processing Record 15 of Set 6 | rouissat
# City not found. Skipping...
# Processing Record 16 of Set 6 | natal
# City not found. Skipping...
# Processing Record 17 of Set 6 | ferkessedougou
# City not found. Skipping...
# Processing Record 18 of Set 6 | umuarama
# City not found. Skipping...
# Processing Record 19 of Set 6 | walvis bay
# City not found. Skipping...
# Processing Record 20 of Set 6 | bamboo flat
# City not found. Skipping...
# Processing Record 21 of Set 6 | la grande
# City not found. Skipping...
# Processing Record 22 of Set 6 | thunder bay
# City not found. Skipping...
# Processing Record 23 of Set 6 | inda silase
# City not found. Skipping...
# Processing Record 24 of Set 6 | pagar alam
# City not found. Skipping...
# Processing Record 25 of Set 6 | fale old settlement
# City not found. Skipping...
# Processing Record 26 of Set 6 | dryden
# City not found. Skipping...
# Processing Record 27 of Set 6 | susuman
# City not found. Skipping...
# Processing Record 28 of Set 6 | kyshtovka
# City not found. Skipping...
# Processing Record 29 of Set 6 | ujae
# City not found. Skipping...
# Processing Record 30 of Set 6 | ozalp
# City not found. Skipping...
# Processing Record 31 of Set 6 | shindand
# City not found. Skipping...
# Processing Record 32 of Set 6 | chokwe
# City not found. Skipping...
# Processing Record 33 of Set 6 | callao
# City not found. Skipping...
# Processing Record 34 of Set 6 | san patricio
# City not found. Skipping...
# Processing Record 35 of Set 6 | shizuishan
# City not found. Skipping...
# Processing Record 36 of Set 6 | alakurtti
# City not found. Skipping...
# Processing Record 37 of Set 6 | minas de marcona
# City not found. Skipping...
# Processing Record 38 of Set 6 | raduzhny
# City not found. Skipping...
# Processing Record 39 of Set 6 | queenstown
# City not found. Skipping...
# Processing Record 40 of Set 6 | saint-philippe
# City not found. Skipping...
# Processing Record 41 of Set 6 | onega
# City not found. Skipping...
# Processing Record 42 of Set 6 | ancud
# City not found. Skipping...
# Processing Record 43 of Set 6 | zhezqazghan
# City not found. Skipping...
# Processing Record 44 of Set 6 | cable beach
# City not found. Skipping...
# Processing Record 45 of Set 6 | samarinda
# City not found. Skipping...
# Processing Record 46 of Set 6 | port-vila
# City not found. Skipping...
# Processing Record 47 of Set 6 | santiago de cao
# City not found. Skipping...
# Processing Record 48 of Set 6 | kaliua
# City not found. Skipping...
# Processing Record 49 of Set 6 | timaru
# City not found. Skipping...
# Processing Record 0 of Set 7 | aasiaat
# City not found. Skipping...
# Processing Record 1 of Set 7 | serenje
# City not found. Skipping...
# Processing Record 2 of Set 7 | hermiston
# City not found. Skipping...
# Processing Record 3 of Set 7 | severo-yeniseyskiy
# City not found. Skipping...
# Processing Record 4 of Set 7 | vingt cinq
# City not found. Skipping...
# Processing Record 5 of Set 7 | la'ie
# City not found. Skipping...
# Processing Record 6 of Set 7 | novouzensk
# City not found. Skipping...
# Processing Record 7 of Set 7 | coquimbo
# City not found. Skipping...
# Processing Record 8 of Set 7 | angaur state
# City not found. Skipping...
# Processing Record 9 of Set 7 | arias
# City not found. Skipping...
# Processing Record 10 of Set 7 | mhamid
# City not found. Skipping...
# Processing Record 11 of Set 7 | campbell river
# City not found. Skipping...
# Processing Record 12 of Set 7 | vostochnyy
# City not found. Skipping...
# Processing Record 13 of Set 7 | suva
# City not found. Skipping...
# Processing Record 14 of Set 7 | puerto baquerizo moreno
# City not found. Skipping...
# Processing Record 15 of Set 7 | antofagasta
# City not found. Skipping...
# Processing Record 16 of Set 7 | kargasok
# City not found. Skipping...
# Processing Record 17 of Set 7 | petropavlovsk-kamchatsky
# City not found. Skipping...
# Processing Record 18 of Set 7 | cam pha mines
# City not found. Skipping...
# Processing Record 19 of Set 7 | punta cana
# City not found. Skipping...
# Processing Record 20 of Set 7 | jayapura
# City not found. Skipping...
# Processing Record 21 of Set 7 | chhor
# City not found. Skipping...
# Processing Record 22 of Set 7 | natchez
# City not found. Skipping...
# Processing Record 23 of Set 7 | rawlins
# City not found. Skipping...
# Processing Record 24 of Set 7 | karabash
# City not found. Skipping...
# Processing Record 25 of Set 7 | port lincoln
# City not found. Skipping...
# Processing Record 26 of Set 7 | mata-utu
# City not found. Skipping...
# Processing Record 27 of Set 7 | kharkhorin
# City not found. Skipping...
# Processing Record 28 of Set 7 | kish
# City not found. Skipping...
# Processing Record 29 of Set 7 | salinas
# City not found. Skipping...
# Processing Record 30 of Set 7 | klaksvik
# City not found. Skipping...
# Processing Record 31 of Set 7 | golyshmanovo
# City not found. Skipping...
# Processing Record 32 of Set 7 | baiao
# City not found. Skipping...
# Processing Record 33 of Set 7 | ad dilam
# City not found. Skipping...
# Processing Record 34 of Set 7 | krasnokholmskiy
# City not found. Skipping...
# Processing Record 35 of Set 7 | fort-shevchenko
# City not found. Skipping...
# Processing Record 36 of Set 7 | yagry
# City not found. Skipping...
# Processing Record 37 of Set 7 | qamdo
# City not found. Skipping...
# Processing Record 38 of Set 7 | asmara
# City not found. Skipping...
# Processing Record 39 of Set 7 | seaside
# City not found. Skipping...
# Processing Record 40 of Set 7 | lubumbashi
# City not found. Skipping...
# Processing Record 41 of Set 7 | ulladulla
# City not found. Skipping...
# Processing Record 42 of Set 7 | ilhabela
# City not found. Skipping...
# Processing Record 43 of Set 7 | murghob
# City not found. Skipping...
# Processing Record 44 of Set 7 | mambajao
# City not found. Skipping...
# Processing Record 45 of Set 7 | meadow lakes
# City not found. Skipping...
# Processing Record 46 of Set 7 | haiku-pauwela
# City not found. Skipping...
# Processing Record 47 of Set 7 | floro
# City not found. Skipping...
# Processing Record 48 of Set 7 | saint-pierre
# City not found. Skipping...
# Processing Record 49 of Set 7 | melfort
# City not found. Skipping...
# Processing Record 0 of Set 8 | iskateley
# City not found. Skipping...
# Processing Record 1 of Set 8 | mana
# City not found. Skipping...
# Processing Record 2 of Set 8 | pristen'
# City not found. Skipping...
# Processing Record 3 of Set 8 | bardai
# City not found. Skipping...
# Processing Record 4 of Set 8 | le vauclin
# City not found. Skipping...
# Processing Record 5 of Set 8 | gongzhuling
# City not found. Skipping...
# Processing Record 6 of Set 8 | sao tome
# City not found. Skipping...
# Processing Record 7 of Set 8 | lensk
# City not found. Skipping...
# Processing Record 8 of Set 8 | aykhal
# City not found. Skipping...
# Processing Record 9 of Set 8 | cargados carajos
# City not found. Skipping...
# Processing Record 10 of Set 8 | ad dabbah
# City not found. Skipping...
# Processing Record 11 of Set 8 | huaibei
# City not found. Skipping...
# Processing Record 12 of Set 8 | balikesir
# City not found. Skipping...
# Processing Record 13 of Set 8 | katsuren-haebaru
# City not found. Skipping...
# Processing Record 14 of Set 8 | xilin hot
# City not found. Skipping...
# Processing Record 15 of Set 8 | arkhangel'sk
# City not found. Skipping...
# Processing Record 16 of Set 8 | macau
# City not found. Skipping...
# Processing Record 17 of Set 8 | eau claire
# City not found. Skipping...
# Processing Record 18 of Set 8 | riohacha
# City not found. Skipping...
# Processing Record 19 of Set 8 | kasese
# City not found. Skipping...
# Processing Record 20 of Set 8 | flying fish cove
# City not found. Skipping...
# Processing Record 21 of Set 8 | balabac
# City not found. Skipping...
# Processing Record 22 of Set 8 | kuanda
# City not found. Skipping...
# Processing Record 23 of Set 8 | mount horeb
# City not found. Skipping...
# Processing Record 24 of Set 8 | manismata
# City not found. Skipping...
# Processing Record 25 of Set 8 | bijawar
# City not found. Skipping...
# Processing Record 26 of Set 8 | igarka
# City not found. Skipping...
# Processing Record 27 of Set 8 | zangguy
# City not found. Skipping...
# Processing Record 28 of Set 8 | uray
# City not found. Skipping...
# Processing Record 29 of Set 8 | lompoc
# City not found. Skipping...
# Processing Record 30 of Set 8 | grande prairie
# City not found. Skipping...
# Processing Record 31 of Set 8 | ciudad lazaro cardenas
# City not found. Skipping...
# Processing Record 32 of Set 8 | tondano
# City not found. Skipping...
# Processing Record 33 of Set 8 | kijang
# City not found. Skipping...
# Processing Record 34 of Set 8 | prieska
# City not found. Skipping...
# Processing Record 35 of Set 8 | dzhalagash
# City not found. Skipping...
# Processing Record 36 of Set 8 | balakirevo
# City not found. Skipping...
# Processing Record 37 of Set 8 | port saint john's
# City not found. Skipping...
# Processing Record 38 of Set 8 | kingscliff
# City not found. Skipping...
# Processing Record 39 of Set 8 | am timan
# City not found. Skipping...
# Processing Record 40 of Set 8 | tokar
# City not found. Skipping...
# Processing Record 41 of Set 8 | sinop
# City not found. Skipping...
# Processing Record 42 of Set 8 | clinton
# City not found. Skipping...
# Processing Record 43 of Set 8 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 44 of Set 8 | zhigalovo
# City not found. Skipping...
# Processing Record 45 of Set 8 | bel ombre
# City not found. Skipping...
# Processing Record 46 of Set 8 | hinton
# City not found. Skipping...
# Processing Record 47 of Set 8 | graaff-reinet
# City not found. Skipping...
# Processing Record 48 of Set 8 | woolgoolga
# City not found. Skipping...
# Processing Record 49 of Set 8 | rafraf
# City not found. Skipping...
# Processing Record 0 of Set 9 | tindouf
# City not found. Skipping...
# Processing Record 1 of Set 9 | hailar
# City not found. Skipping...
# Processing Record 2 of Set 9 | jesenik
# City not found. Skipping...
# Processing Record 3 of Set 9 | edd
# City not found. Skipping...
# Processing Record 4 of Set 9 | harper
# City not found. Skipping...
# Processing Record 5 of Set 9 | mournies
# City not found. Skipping...
# Processing Record 6 of Set 9 | paredon
# City not found. Skipping...
# Processing Record 7 of Set 9 | piacabucu
# City not found. Skipping...
# Processing Record 8 of Set 9 | fortuna foothills
# City not found. Skipping...
# Processing Record 9 of Set 9 | gimcheon
# City not found. Skipping...
# Processing Record 10 of Set 9 | borba
# City not found. Skipping...
# Processing Record 11 of Set 9 | dara
# City not found. Skipping...
# Processing Record 12 of Set 9 | altamira
# City not found. Skipping...
# Processing Record 13 of Set 9 | taber
# City not found. Skipping...
# Processing Record 14 of Set 9 | bougouni
# City not found. Skipping...
# Processing Record 15 of Set 9 | yung shue wan
# City not found. Skipping...
# Processing Record 16 of Set 9 | malanje
# City not found. Skipping...
# Processing Record 17 of Set 9 | dayr mawas
# City not found. Skipping...
# Processing Record 18 of Set 9 | katsuura
# City not found. Skipping...
# Processing Record 19 of Set 9 | baruun-urt
# City not found. Skipping...
# Processing Record 20 of Set 9 | vila do maio
# City not found. Skipping...
# Processing Record 21 of Set 9 | nuuk
# City not found. Skipping...
# Processing Record 22 of Set 9 | kolonia
# City not found. Skipping...
# Processing Record 23 of Set 9 | jalai nur
# City not found. Skipping...
# Processing Record 24 of Set 9 | moose jaw
# City not found. Skipping...
# Processing Record 25 of Set 9 | eaglehawk
# City not found. Skipping...
# Processing Record 26 of Set 9 | isla del bosque
# City not found. Skipping...
# Processing Record 27 of Set 9 | fiambala
# City not found. Skipping...
# Processing Record 28 of Set 9 | margate
# City not found. Skipping...
# Processing Record 29 of Set 9 | mejit
# City not found. Skipping...
# Processing Record 30 of Set 9 | puerto real
# City not found. Skipping...
# Processing Record 31 of Set 9 | caleta de carquin
# City not found. Skipping...
# Processing Record 32 of Set 9 | sirte
# City not found. Skipping...
# Processing Record 33 of Set 9 | tanrake village
# City not found. Skipping...
# Processing Record 34 of Set 9 | hauterive
# City not found. Skipping...
# Processing Record 35 of Set 9 | mangrol
# City not found. Skipping...
# Processing Record 36 of Set 9 | vorgashor
# City not found. Skipping...
# Processing Record 37 of Set 9 | north bend
# City not found. Skipping...
# Processing Record 38 of Set 9 | papao
# City not found. Skipping...
# Processing Record 39 of Set 9 | el nido
# City not found. Skipping...
# Processing Record 40 of Set 9 | basco
# City not found. Skipping...
# Processing Record 41 of Set 9 | aral
# City not found. Skipping...
# Processing Record 42 of Set 9 | ilebo
# City not found. Skipping...
# Processing Record 43 of Set 9 | maryborough
# City not found. Skipping...
# Processing Record 44 of Set 9 | mount pleasant
# City not found. Skipping...
# Processing Record 45 of Set 9 | grand falls-windsor
# City not found. Skipping...
# Processing Record 46 of Set 9 | sokoni
# City not found. Skipping...
# Processing Record 47 of Set 9 | pelabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 9 | kwang binh
# City not found. Skipping...
# Processing Record 49 of Set 9 | cabo san lucas
# City not found. Skipping...
# Processing Record 0 of Set 10 | uturoa
# City not found. Skipping...
# Processing Record 1 of Set 10 | pamanukan
# City not found. Skipping...
# Processing Record 2 of Set 10 | ardakan
# City not found. Skipping...
# Processing Record 3 of Set 10 | toliara
# City not found. Skipping...
# Processing Record 4 of Set 10 | nemuro
# City not found. Skipping...
# Processing Record 5 of Set 10 | presidente dutra
# City not found. Skipping...
# Processing Record 6 of Set 10 | kitgum
# City not found. Skipping...
# Processing Record 7 of Set 10 | grants
# City not found. Skipping...
# Processing Record 8 of Set 10 | nsanje
# City not found. Skipping...
# Processing Record 9 of Set 10 | san rafael
# City not found. Skipping...
# Processing Record 10 of Set 10 | al kharijah
# City not found. Skipping...
# Processing Record 11 of Set 10 | sur
# City not found. Skipping...
# Processing Record 12 of Set 10 | mandimba
# City not found. Skipping...
# Processing Record 13 of Set 10 | bikin
# City not found. Skipping...
# Processing Record 14 of Set 10 | erenhot
# City not found. Skipping...
# Processing Record 15 of Set 10 | tilcara
# City not found. Skipping...
# Processing Record 16 of Set 10 | tromso
# City not found. Skipping...
# Processing Record 17 of Set 10 | ketchikan
# City not found. Skipping...
# Processing Record 18 of Set 10 | ingeniero guillermo n. juarez
# City not found. Skipping...
# Processing Record 19 of Set 10 | cozumel
# City not found. Skipping...
# Processing Record 20 of Set 10 | trossingen
# City not found. Skipping...
# Processing Record 21 of Set 10 | kiunga
# City not found. Skipping...
# Processing Record 22 of Set 10 | ishinomaki
# City not found. Skipping...
# Processing Record 23 of Set 10 | saint-joseph
# City not found. Skipping...
# Processing Record 24 of Set 10 | kaitong
# City not found. Skipping...
# Processing Record 25 of Set 10 | manuel ojinaga
# City not found. Skipping...
# Processing Record 26 of Set 10 | santa rita
# City not found. Skipping...
# Processing Record 27 of Set 10 | ventspils
# City not found. Skipping...
# Processing Record 28 of Set 10 | kani keli
# City not found. Skipping...
# Processing Record 29 of Set 10 | fuglafjordur
# City not found. Skipping...
# Processing Record 30 of Set 10 | sassandra
# City not found. Skipping...
# Processing Record 31 of Set 10 | surskoye
# City not found. Skipping...
# Processing Record 32 of Set 10 | chidawa
# City not found. Skipping...
# Processing Record 33 of Set 10 | souillac
# City not found. Skipping...
# Processing Record 34 of Set 10 | puerto deseado
# City not found. Skipping...
# Processing Record 35 of Set 10 | vila velha
# City not found. Skipping...
# Processing Record 36 of Set 10 | xi'an
# City not found. Skipping...
# Processing Record 37 of Set 10 | arteche
# City not found. Skipping...
# Processing Record 38 of Set 10 | yangambi
# City not found. Skipping...
# Processing Record 39 of Set 10 | hasaki
# City not found. Skipping...
# Processing Record 40 of Set 10 | nizhneangarsk
# City not found. Skipping...
# Processing Record 41 of Set 10 | kirillov
# City not found. Skipping...
# Processing Record 42 of Set 10 | kunming
# City not found. Skipping...
# Processing Record 43 of Set 10 | eloy
# City not found. Skipping...
# Processing Record 44 of Set 10 | calama
# City not found. Skipping...
# Processing Record 45 of Set 10 | praia da vitoria
# City not found. Skipping...
# Processing Record 46 of Set 10 | shipunovo
# City not found. Skipping...
# Processing Record 47 of Set 10 | olinda
# City not found. Skipping...
# Processing Record 48 of Set 10 | yurimaguas
# City not found. Skipping...
# Processing Record 49 of Set 10 | tulum
# City not found. Skipping...
# Processing Record 0 of Set 11 | berezovo
# City not found. Skipping...
# Processing Record 1 of Set 11 | castillos
# City not found. Skipping...
# Processing Record 2 of Set 11 | cooma
# City not found. Skipping...
# Processing Record 3 of Set 11 | colonia
# City not found. Skipping...
# Processing Record 4 of Set 11 | taroudant
# City not found. Skipping...
# Processing Record 5 of Set 11 | dawesville
# City not found. Skipping...
# Processing Record 6 of Set 11 | ploneour-lanvern
# City not found. Skipping...
# Processing Record 7 of Set 11 | bryne
# City not found. Skipping...
# Processing Record 8 of Set 11 | liman
# City not found. Skipping...
# Processing Record 9 of Set 11 | wad az zaki
# City not found. Skipping...
# Processing Record 10 of Set 11 | griffith
# City not found. Skipping...
# Processing Record 11 of Set 11 | halmstad
# City not found. Skipping...
# Processing Record 12 of Set 11 | birzebbuga
# City not found. Skipping...
# Processing Record 13 of Set 11 | saldanha
# City not found. Skipping...
# Processing Record 14 of Set 11 | carutapera
# City not found. Skipping...
# Processing Record 15 of Set 11 | loa janan
# City not found. Skipping...
# Processing Record 16 of Set 11 | muroto-misakicho
# City not found. Skipping...
# Processing Record 17 of Set 11 | alo
# City not found. Skipping...
# Processing Record 18 of Set 11 | chui
# City not found. Skipping...
# Processing Record 19 of Set 11 | marka
# City not found. Skipping...
# Processing Record 20 of Set 11 | bandarbeyla
# City not found. Skipping...
# Processing Record 21 of Set 11 | laascaanood
# City not found. Skipping...
# Processing Record 22 of Set 11 | wyszkow
# City not found. Skipping...
# Processing Record 23 of Set 11 | chibougamau
# City not found. Skipping...
# Processing Record 24 of Set 11 | gadzhiyevo
# City not found. Skipping...
# Processing Record 25 of Set 11 | labrador city
# City not found. Skipping...
# Processing Record 26 of Set 11 | sinan
# City not found. Skipping...
# Processing Record 27 of Set 11 | tynda
# City not found. Skipping...
# Processing Record 28 of Set 11 | hamada
# City not found. Skipping...
# Processing Record 29 of Set 11 | fort st. john
# City not found. Skipping...
# Processing Record 30 of Set 11 | antalaha
# City not found. Skipping...
# Processing Record 31 of Set 11 | micheweni
# City not found. Skipping...
# Processing Record 32 of Set 11 | freetown
# City not found. Skipping...
# Processing Record 33 of Set 11 | kodinsk
# City not found. Skipping...
# Processing Record 34 of Set 11 | anadyr
# City not found. Skipping...
# Processing Record 35 of Set 11 | tabou
# City not found. Skipping...
# Processing Record 36 of Set 11 | prado
# City not found. Skipping...
# Processing Record 37 of Set 11 | dalmatovo
# City not found. Skipping...
# Processing Record 38 of Set 11 | nichinan
# City not found. Skipping...
# Processing Record 39 of Set 11 | nyurba
# City not found. Skipping...
# Processing Record 40 of Set 11 | aconibe
# City not found. Skipping...
# Processing Record 41 of Set 11 | nova xavantina
# City not found. Skipping...
# Processing Record 42 of Set 11 | magadan
# City not found. Skipping...
# Processing Record 43 of Set 11 | camargo
# City not found. Skipping...
# Processing Record 44 of Set 11 | ta`u
# City not found. Skipping...
# Processing Record 45 of Set 11 | fuvahmulah
# City not found. Skipping...
# Processing Record 46 of Set 11 | oroqen zizhiqi
# City not found. Skipping...
# Processing Record 47 of Set 11 | northam
# City not found. Skipping...
# Processing Record 48 of Set 11 | zaozersk
# City not found. Skipping...
# Processing Record 49 of Set 11 | sharm el-sheikh
# City not found. Skipping...
# Processing Record 0 of Set 12 | rikaze
# City not found. Skipping...
# Processing Record 1 of Set 12 | westport
# City not found. Skipping...
# Processing Record 2 of Set 12 | pingliang
# City not found. Skipping...
# Processing Record 3 of Set 12 | santa ana de yacuma
# City not found. Skipping...
# Processing Record 4 of Set 12 | mount isa
# City not found. Skipping...
# Processing Record 5 of Set 12 | krasnaya gora
# City not found. Skipping...
# Processing Record 6 of Set 12 | banda aceh
# City not found. Skipping...
# Processing Record 7 of Set 12 | codrington
# City not found. Skipping...
# Processing Record 8 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 9 of Set 12 | akrehamn
# City not found. Skipping...
# Processing Record 10 of Set 12 | kuta
# City not found. Skipping...
# Processing Record 11 of Set 12 | nogliki
# City not found. Skipping...
# Processing Record 12 of Set 12 | bismarck
# City not found. Skipping...
# Processing Record 13 of Set 12 | adh dhibiyah
# City not found. Skipping...
# Processing Record 14 of Set 12 | masterton
# City not found. Skipping...
# Processing Record 15 of Set 12 | kirakira
# City not found. Skipping...
# Processing Record 16 of Set 12 | baringo
# City not found. Skipping...
# Processing Record 17 of Set 12 | quellon
# City not found. Skipping...
# Processing Record 18 of Set 12 | biltine
# City not found. Skipping...
# Processing Record 19 of Set 12 | enniskillen
# City not found. Skipping...
# Processing Record 20 of Set 12 | bargaal
# City not found. Skipping...
# Processing Record 21 of Set 12 | kutum
# City not found. Skipping...
# Processing Record 22 of Set 12 | tranovaho
# City not found. Skipping...
# Processing Record 23 of Set 12 | puerto asis
# City not found. Skipping...
# Processing Record 24 of Set 12 | sinabang
# City not found. Skipping...
# Processing Record 25 of Set 12 | ayr
# City not found. Skipping...
# Processing Record 26 of Set 12 | xinzhi
# City not found. Skipping...
# Processing Record 27 of Set 12 | tome acu
# City not found. Skipping...
# Processing Record 28 of Set 12 | black point
# City not found. Skipping...
# Processing Record 29 of Set 12 | sale
# City not found. Skipping...
# Processing Record 30 of Set 12 | karagay
# City not found. Skipping...
# Processing Record 31 of Set 12 | semenov
# City not found. Skipping...
# Processing Record 32 of Set 12 | kursunlu
# City not found. Skipping...
# Processing Record 33 of Set 12 | ryotsu-minato
# City not found. Skipping...
# Processing Record 34 of Set 12 | ghanzi
# City not found. Skipping...
# Processing Record 35 of Set 12 | mandan
# City not found. Skipping...
# Processing Record 36 of Set 12 | nar'yan-mar
# City not found. Skipping...
# Processing Record 37 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 38 of Set 12 | rongelap
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# Series([], dtype: int64)

# %%
# Display sample data
city_data_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.figure(figsize=(10, 6))
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], marker='o', color='blue', edgecolors='black', alpha=0.7)

# Incorporate the other graph properties
plt.title('City Latitude vs. Max Temperature', fontsize=14)  # Title of the plot
plt.xlabel('Latitude', fontsize=12)  # Label for the x-axis
plt.ylabel('Max Temperature (°C)', fontsize=12)  # Label for the y-axis
plt.grid(True)  # Enable grid for better readability

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Lat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Build scatter plot for latitude vs. temperature
#       2 plt.figure(figsize=(10, 6))
# ----> 3 plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], marker='o', color='blue', edgecolors='black', alpha=0.7)
#       5 # Incorporate the other graph properties
#       6 plt.title('City Latitude vs. Max Temperature', fontsize=14)  # Title of the plot
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Lat'

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.figure(figsize=(10, 6))
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], marker='o', color='green', edgecolors='black', alpha=0.7)

# Incorporate the other graph properties
plt.title('City Latitude vs. Humidity', fontsize=14)  # Title of the plot
plt.xlabel('Latitude', fontsize=12)  # Label for the x-axis
plt.ylabel('Humidity (%)', fontsize=12)  # Label for the y-axis
plt.grid(True)  # Enable grid for better readability

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.figure(figsize=(10, 6))
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], marker='o', color='green', edgecolors='black', alpha=0.7)

# Incorporate the other graph properties
plt.title('City Latitude vs. Cloudiness', fontsize=14)  # Title of the plot
plt.xlabel('Latitude', fontsize=12)  # Label for the x-axis
plt.ylabel('Cloudiness (%)', fontsize=12)  # Label for the y-axis
plt.grid(True)  # Enable grid for better readability

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.figure(figsize=(10, 6))
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], marker='o', color='green', edgecolors='black', alpha=0.7)

# Incorporate the other graph properties
plt.title('City Latitude vs. Wind Speed', fontsize=14)  # Title of the plot
plt.xlabel('Latitude', fontsize=12)  # Label for the x-axis
plt.ylabel('Wind Speed (m/s)', fontsize=12)  # Label for the y-axis
plt.grid(True)  # Enable grid for better readability

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x, y, x_label, y_label, title, filename):
    slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
    
    # Create the regression line
    regression_line = slope * np.array(x) + intercept

    # Create the plot
    plt.figure(figsize=(10, 6))
    plt.scatter(x, y, marker='o', color='blue', edgecolors='black', alpha=0.7, label='Data Points')  # Scatter plot
    plt.plot(x, regression_line, color='red', label=f'Linear Regression Line: y = {slope:.2f}x + {intercept:.2f}')  # Regression line

    # Add titles and labels
    plt.title(title, fontsize=14)
    plt.xlabel(x_label, fontsize=12)
    plt.ylabel(y_label, fontsize=12)
    plt.grid(True)
    plt.legend()

    # Save the figure
    plt.savefig(filename)

    # Show the plot
    plt.show()

    # Return the linear regression details (slope, intercept, R-squared, p-value)
    return slope, intercept, r_value**2, p_value, std_err

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
slope_north, intercept_north, r_value_north, p_value_north, std_err_north = plot_linear_regression(
    northern_hemi_df['Lat'], 
    northern_hemi_df['Max Temp'], 
    'Latitude', 
    'Max Temperature (°C)', 
    'Northern Hemisphere: Temperature vs. Latitude', 
    'output_data/North_Temperature_vs_Latitude.png'
)

# %%
# Linear regression on Southern Hemisphere
slope_south, intercept_south, r_value_south, p_value_south, std_err_south = plot_linear_regression(
    southern_hemi_df['Lat'], 
    southern_hemi_df['Max Temp'], 
    'Latitude', 
    'Max Temperature (°C)', 
    'Southern Hemisphere: Temperature vs. Latitude', 
    'output_data/South_Temperature_vs_Latitude.png'
)

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Perform linear regression: latitude vs. humidity
slope, intercept, r_value, p_value, std_err = stats.linregress(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])

# Create the regression line based on the linear regression output
regression_line = slope * np.array(northern_hemi_df['Lat']) + intercept

# Create the scatter plot with the regression line
plt.figure(figsize=(10, 6))
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], color='blue', edgecolors='black', alpha=0.7, label='Data Points')

# Plot the regression line
plt.plot(northern_hemi_df['Lat'], regression_line, color='red', label=f'Linear Regression Line: y = {slope:.2f}x + {intercept:.2f}')

# Add titles and labels
plt.title('Northern Hemisphere: Latitude vs. Humidity', fontsize=14)
plt.xlabel('Latitude', fontsize=12)
plt.ylabel('Humidity (%)', fontsize=12)
plt.grid(True)
plt.legend()

# Save the plot
plt.savefig("output_data/Northern_Hemisphere_Latitude_vs_Humidity.png")

# Show the plot
plt.show()

# Print the linear regression statistics
print(f"Linear Regression (Northern Hemisphere):")
print(f"Slope: {slope:.2f}")
print(f"Intercept: {intercept:.2f}")
print(f"R-squared: {r_value**2:.2f}")
print(f"P-value: {p_value:.4f}")
print(f"Standard Error: {std_err:.4f}")

# %%
# Southern Hemisphere

# Perform linear regression: latitude vs. humidity
slope, intercept, r_value, p_value, std_err = stats.linregress(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])

# Create the regression line based on the linear regression output
regression_line = slope * np.array(southern_hemi_df['Lat']) + intercept

# Create the scatter plot with the regression line
plt.figure(figsize=(10, 6))
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], color='green', edgecolors='black', alpha=0.7, label='Data Points')

# Plot the regression line
plt.plot(southern_hemi_df['Lat'], regression_line, color='red', label=f'Linear Regression Line: y = {slope:.2f}x + {intercept:.2f}')

# Add titles and labels
plt.title('Southern Hemisphere: Latitude vs. Humidity', fontsize=14)
plt.xlabel('Latitude', fontsize=12)
plt.ylabel('Humidity (%)', fontsize=12)
plt.grid(True)
plt.legend()

# Save the plot
plt.savefig("output_data/Southern_Hemisphere_Latitude_vs_Humidity.png")

# Show the plot
plt.show()

# Print the linear regression statistics
print(f"Linear Regression (Southern Hemisphere):")
print(f"Slope: {slope:.2f}")
print(f"Intercept: {intercept:.2f}")
print(f"R-squared: {r_value**2:.2f}")
print(f"P-value: {p_value:.4f}")
print(f"Standard Error: {std_err:.4f}")

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Filter data for Northern Hemisphere (latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Perform linear regression: latitude vs. cloudiness
slope, intercept, r_value, p_value, std_err = stats.linregress(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])

# Create the regression line based on the linear regression output
regression_line = slope * np.array(northern_hemi_df['Lat']) + intercept

# Create the scatter plot with the regression line
plt.figure(figsize=(10, 6))
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'], color='purple', edgecolors='black', alpha=0.7, label='Data Points')

# Plot the regression line
plt.plot(northern_hemi_df['Lat'], regression_line, color='red', label=f'Linear Regression Line: y = {slope:.2f}x + {intercept:.2f}')

# Add titles and labels
plt.title('Northern Hemisphere: Latitude vs. Cloudiness', fontsize=14)
plt.xlabel('Latitude', fontsize=12)
plt.ylabel('Cloudiness (%)', fontsize=12)
plt.grid(True)
plt.legend()

# Save the plot
plt.savefig("output_data/Northern_Hemisphere_Latitude_vs_Cloudiness.png")

# Show the plot
plt.show()

# Print the linear regression statistics
print(f"Linear Regression (Northern Hemisphere) for Cloudiness:")
print(f"Slope: {slope:.2f}")
print(f"Intercept: {intercept:.2f}")
print(f"R-squared: {r_value**2:.2f}")
print(f"P-value: {p_value:.4f}")
print(f"Standard Error: {std_err:.4f}")

# %%
# Southern Hemisphere
# Filter data for Southern Hemisphere (latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Perform linear regression: latitude vs. cloudiness
slope, intercept, r_value, p_value, std_err = stats.linregress(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])

# Create the regression line based on the linear regression output
regression_line = slope * np.array(southern_hemi_df['Lat']) + intercept

# Create the scatter plot with the regression line
plt.figure(figsize=(10, 6))
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'], color='orange', edgecolors='black', alpha=0.7, label='Data Points')

# Plot the regression line
plt.plot(southern_hemi_df['Lat'], regression_line, color='red', label=f'Linear Regression Line: y = {slope:.2f}x + {intercept:.2f}')

# Add titles and labels
plt.title('Southern Hemisphere: Latitude vs. Cloudiness', fontsize=14)
plt.xlabel('Latitude', fontsize=12)
plt.ylabel('Cloudiness (%)', fontsize=12)
plt.grid(True)
plt.legend()

# Save the plot
plt.savefig("output_data/Southern_Hemisphere_Latitude_vs_Cloudiness.png")

# Show the plot
plt.show()

# Print the linear regression statistics
print(f"Linear Regression (Southern Hemisphere) for Cloudiness:")
print(f"Slope: {slope:.2f}")
print(f"Intercept: {intercept:.2f}")
print(f"R-squared: {r_value**2:.2f}")
print(f"P-value: {p_value:.4f}")
print(f"Standard Error: {std_err:.4f}")

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Filter data for Northern Hemisphere (latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Perform linear regression: latitude vs. wind speed
slope, intercept, r_value, p_value, std_err = stats.linregress(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])

# Create the regression line based on the linear regression output
regression_line = slope * np.array(northern_hemi_df['Lat']) + intercept

# Create the scatter plot with the regression line
plt.figure(figsize=(10, 6))
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'], color='blue', edgecolors='black', alpha=0.7, label='Data Points')

# Plot the regression line
plt.plot(northern_hemi_df['Lat'], regression_line, color='red', label=f'Linear Regression Line: y = {slope:.2f}x + {intercept:.2f}')

# Add titles and labels
plt.title('Northern Hemisphere: Latitude vs. Wind Speed', fontsize=14)
plt.xlabel('Latitude', fontsize=12)
plt.ylabel('Wind Speed (m/s)', fontsize=12)
plt.grid(True)
plt.legend()

# Save the plot
plt.savefig("output_data/Northern_Hemisphere_Latitude_vs_Wind_Speed.png")

# Show the plot
plt.show()

# Print the linear regression statistics
print(f"Linear Regression (Northern Hemisphere) for Wind Speed:")
print(f"Slope: {slope:.2f}")
print(f"Intercept: {intercept:.2f}")
print(f"R-squared: {r_value**2:.2f}")
print(f"P-value: {p_value:.4f}")
print(f"Standard Error: {std_err:.4f}")

# %%
# Southern Hemisphere
# Filter data for Southern Hemisphere (latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Perform linear regression: latitude vs. wind speed
slope, intercept, r_value, p_value, std_err = stats.linregress(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])

# Create the regression line based on the linear regression output
regression_line = slope * np.array(southern_hemi_df['Lat']) + intercept

# Create the scatter plot with the regression line
plt.figure(figsize=(10, 6))
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], color='green', edgecolors='black', alpha=0.7, label='Data Points')

# Plot the regression line
plt.plot(southern_hemi_df['Lat'], regression_line, color='red', label=f'Linear Regression Line: y = {slope:.2f}x + {intercept:.2f}')

# Add titles and labels
plt.title('Southern Hemisphere: Latitude vs. Wind Speed', fontsize=14)
plt.xlabel('Latitude', fontsize=12)
plt.ylabel('Wind Speed (m/s)', fontsize=12)
plt.grid(True)
plt.legend()

# Save the plot
plt.savefig("output_data/Southern_Hemisphere_Latitude_vs_Wind_Speed.png")

# Show the plot
plt.show()

# Print the linear regression statistics
print(f"Linear Regression (Southern Hemisphere) for Wind Speed:")
print(f"Slope: {slope:.2f}")
print(f"Intercept: {intercept:.2f}")
print(f"R-squared: {r_value**2:.2f}")
print(f"P-value: {p_value:.4f}")
print(f"Standard Error: {std_err:.4f}")

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
